# %%
from google.colab import drive
import os
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Colab Notebooks/PRSM')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Wed Aug 30 09:38:37 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# 单个模型训练：设置lambda=0.8，测试集占比0.136，使用数据集子集，子特征数量10000个
# %run scripts/train.py --regularization_strength 0.8 \
                      --testing_set_ratio 0.136 \
                      --num_subset_feature
# Out:
# {'DATASET_DIR_BASE': './datasets',
#  'LIB_DIR_BASE': './',
#  'OUTPUS_DIR_ROOT': './outputs',
#  'SEED': 42}
# Namespace(regularization_strength=0.8, testing_set_ratio=0.136, use_full_dataset=False, num_subset_feature=10000)
# Read dataset of shape (2314, 52848)
# Header fragments are shown below:
# [[-8.68703500e-01  2.81584950e-01  1.71659645e+00 -8.86106400e-01
#    4.76114438e+01  1.00000000e+00]
#  [ 1.31444170e-01 -1.74683540e+00  9.52725930e-01  1.58435810e-01
#   -4.19402120e+01  1.00000000e+00]
#  [-8.53601300e-01 -2.99680450e+00 -8.71332000e-02 -1.21775780e+00
#    1.00653792e+02  1.00000000e+00]
#  [ 3.41678500e-02 -3.20321000e-01 -7.11890000e-02 -1.46728030e+00
#    1.38808255e+01  1.00000000e+00]
#  [ 5.73911410e-01 -2.04583740e+00  5.47430000e-02  1.64027080e-01
#   -5.87386740e+01  2.00000000e+00]]
# ndarray shuffled in place with seed 42.
# Sanity checking: the original 0-th row has been moved to 772-th line.
# Normalizing across all rows...
# Sanity checking: The 0-th column of size (2314,) now has -7.676563696630296e-17 mean and 1.0 std.
# Split 2314 samples in total into 2000 training samples and 314 testing samples.
# train_feature.shape (2000, 9995)
# train_label.shape (2000, 5)
# test_feature.shape (314, 9995)
# test_label.shape (314, 5)
# ----------
# Model Config Template:
# Data:
# 	x_train: shape (0,)
# 	y_train: shape (0,)
# Parameters:
# 	lambda: 0
# 	e: 0
# 	maxIteration: 0
# Configs:
# 	repo: None
# 	verbose: True
# 	overrideUnfinished: True
# ----------
# ----------
# lambda=0.8
# e=0.01
# training_time=19.39s
# iterations=426
# final_loss=139.23593139648438
# final_training_mse=0.539526104927063
# final_nonzero_coef_num=49975
# final_testing_mse=23337.557750017997
# ----------
# Log file saved to ./outputs/prsm_admm_report.txt

# %%
# 10折交叉验证：设置测试集占比0.136，使用数据集子集，子特征数量10000个
# %run scripts/kfold_cv.py --testing_set_ratio 0.136 \
                      --num_subset_feature
# Out:
# {'DATASET_DIR_BASE': './datasets',
#  'LIB_DIR_BASE': './',
#  'OUTPUS_DIR_ROOT': './outputs',
#  'SEED': 42}
# Namespace(regularization_strength=100, testing_set_ratio=0.136, use_full_dataset=False, num_subset_feature=10000)
# Read dataset of shape (2314, 52848)
# Header fragments are shown below:
# [[-8.68703500e-01  2.81584950e-01  1.71659645e+00 -8.86106400e-01
#    4.76114438e+01  1.00000000e+00]
#  [ 1.31444170e-01 -1.74683540e+00  9.52725930e-01  1.58435810e-01
#   -4.19402120e+01  1.00000000e+00]
#  [-8.53601300e-01 -2.99680450e+00 -8.71332000e-02 -1.21775780e+00
#    1.00653792e+02  1.00000000e+00]
#  [ 3.41678500e-02 -3.20321000e-01 -7.11890000e-02 -1.46728030e+00
#    1.38808255e+01  1.00000000e+00]
#  [ 5.73911410e-01 -2.04583740e+00  5.47430000e-02  1.64027080e-01
#   -5.87386740e+01  2.00000000e+00]]
# ndarray shuffled in place with seed 42.
# Sanity checking: the original 0-th row has been moved to 772-th line.
# Normalizing across all rows...
# Sanity checking: The 0-th column of size (2314,) now has -7.676563696630296e-17 mean and 1.0 std.
# Split 2314 samples in total into 2000 training samples and 314 testing samples.
# train_feature.shape (2000, 9995)
# train_label.shape (2000, 5)
# test_feature.shape (314, 9995)
# test_label.shape (314, 5)
# ----------
# i_fold=0
# lambda=0.0001
# e=0.01
# training_time=14.35s
# iterations=37
# final_loss=854.1510620117188
# final_training_mse=0.0007736159604974091
# final_nonzero_coef_num=49975
# final_testing_mse=22546.081320636993
# ----------
# Log file saved to ./outputs/prsm_admm_cv_report.txt
# ----------
# i_fold=1
# lambda=0.0001
# e=0.01
# training_time=14.05s
# iterations=38
# final_loss=856.4347534179688
# final_training_mse=0.0006489435327239335
# final_nonzero_coef_num=49975
# final_testing_mse=21449.100283227024
# ----------
# Log file saved to ./outputs/prsm_admm_cv_report.txt
# ----------
# Model Config:
# Data:
# 	x_train: shape (200, 9995)
# 	y_train: shape (200, 5)
# Parameters:
# 	lambda: 0.0001
# 	e: 0.01
# 	maxIteration: 1500
# 	i_fold: 2
# Configs:
# 	repo: Repository(name="prsm_admm_cv", IdentityFields=['lambda', 'e', 'maxIteration', 'i_fold'])
# 	verbose: True
# 	overrideUnfinished: True
# ----------
# Model Initializing...
# Float Precision: float32
#   0%|          | 0/1500 [00:00<?, ?it/s]
# ----------
# i_fold=2
# lambda=0.0001
# e=0.01
# training_time=14.01s
# iterations=38
# final_loss=857.1867065429688
# final_training_mse=0.0005412625032477081
# final_nonzero_coef_num=49975
# final_testing_mse=21536.103183594194
# ----------
# Log file saved to ./outputs/prsm_admm_cv_report.txt
# ----------
# Model Config:
# Data:
# 	x_train: shape (200, 9995)
# 	y_train: shape (200, 5)
# Parameters:
# 	lambda: 0.0001
# 	e: 0.01
# 	maxIteration: 1500
# 	i_fold: 3
# Configs:
# 	repo: Repository(name="prsm_admm_cv", IdentityFields=['lambda', 'e', 'maxIteration', 'i_fold'])
# 	verbose: True
# 	overrideUnfinished: True
# ----------
# Model Initializing...
# Float Precision: float32
#   0%|          | 0/1500 [00:00<?, ?it/s]
