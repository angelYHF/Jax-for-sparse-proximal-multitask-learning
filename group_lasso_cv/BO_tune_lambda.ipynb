# %%
# !nvidia-smi
# Out:
# Mon Apr  3 09:20:14 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   53C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
import os
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Colab Notebooks/bo_tune_lambda')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pip install bayesian-optimization
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python lambda_tuning.py --override
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/bo_tune_lambda/lambda_tuning.py", line 97, in <module>
#     optimizer.maximize(
#   File "/usr/local/lib/python3.9/dist-packages/bayes_opt/bayesian_optimization.py", line 311, in maximize
#     self.probe(x_probe, lazy=False)
#   File "/usr/local/lib/python3.9/dist-packages/bayes_opt/bayesian_optimization.py", line 208, in probe
#     self._space.probe(params)
#   File "/usr/local/lib/python3.9/dist-packages/bayes_opt/target_space.py", line 239, in probe
#     self.register(x, target)
#   File "/usr/local/lib/python3.9/dist-packages/bayes_opt/target_space.py", line 196, in register
#     raise NotUniqueError(f'Data point {x} is not unique. You can set "allow_duplicate_points=True" to '
# bayes_opt.util.NotUniqueError: Data point [25.    0.05] is not unique. You can set "allow_duplicate_points=True" to avoid this error
