# %%
from google.colab import drive
import os
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Colab Notebooks/group_lasso_cv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !/usr/bin/env bash ./train.sh
# Out:
# Total Progress(find e): 100% 4/4 [00:00<00:00, 1647.41it/s]
# Total Progress(find lambda): 100% 42/42 [00:00<00:00, 124.97it/s]
