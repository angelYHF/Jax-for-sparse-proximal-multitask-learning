# %%
from google.colab import drive
import os
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Colab Notebooks/scprsm')
# Out:
# Mounted at /content/drive

# %%
# 单个模型训练：设置lambda=0.8，测试集占比0.136，使用数据集子集，子特征数量10000个
# %run scripts/train.py --regularization_strength 0.8 \
                      --testing_set_ratio 0.136 \
                      --use_full_dataset True
# Out:
# {'DATASET_DIR_BASE': './datasets',
#  'LIB_DIR_BASE': './',
#  'OUTPUS_DIR_ROOT': './outputs',
#  'SEED': 42}
# Namespace(regularization_strength=0.8, testing_set_ratio=0.136, use_full_dataset=True, num_subset_feature=None)
# Read dataset of shape (1813, 10348)
# Header fragments are shown below:
# [[ 0.7436378   0.03704377  1.          1.          2.          1.        ]
#  [ 0.43108631 -0.08243445  2.          0.          2.          2.        ]
#  [ 0.14443339  0.01791076  1.          1.          1.          1.        ]
#  [ 0.67536591 -0.04014835  2.          0.          2.          2.        ]
#  [-0.65813335  0.04312351  1.          1.          1.          1.        ]]
# ndarray shuffled in place with seed 42.
# Sanity checking: the original 0-th row has been moved to 657-th line.
# Normalizing across all rows...
# Sanity checking: The 0-th column of size (1813,) now has -3.7231969055272764e-17 mean and 1.0 std.
# ...

# %%
# 10折交叉验证：设置测试集占比0.136，使用数据集子集，子特征数量10000个
# %run scripts/kfold_cv.py --testing_set_ratio 0.136 \
                      --use_full_dataset True
